# %%
import matplotlib.pyplot as plt

labels = ["UPI", "Card", "Cash"]
sizes = [95, 2, 3]

fig2, ax2 = plt.subplots()
ax2.pie(sizes, labels=labels, autopct='%1.f%%', startangle=60)
ax2.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
